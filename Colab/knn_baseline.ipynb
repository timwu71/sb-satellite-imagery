# %% [markdown]
# This code is adapted from the SustainBench knn_baseline.ipynb found at https://github.com/sustainlab-group/sustainbench/blob/main/baseline_models/dhs/knn_baseline.ipynb.

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Enter the foldername for the data set (added shortcut to 230/231N folder)
FOLDERNAME = 'Shareddrives/CS 230 231N/public_datasets'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
dataset_path = '/content/drive/My Drive/{}'.format(FOLDERNAME)
# sys.path.append(dataset_path)

# %%
from concurrent.futures import ThreadPoolExecutor
import os

import numpy as np
import pandas as pd
import sklearn
from tqdm.auto import tqdm

# %%
df = pd.read_csv(os.path.join(dataset_root_dir, 'output_labels/dhs_final_labels.csv'))
df['survey'] = df['DHSID_EA'].str[:10]
df['cc'] = df['DHSID_EA'].str[:2]

# stores path to each satellite image in df['path']
data_dir = '/content/drive/Shareddrives/CS 230 231N/dhs_datasets/'
df['path'] = data_dir + df['survey'] + '/' + df['DHSID_EA'] + '.npz'


path_years = df[['DHSID_EA', 'path', 'year']].apply(tuple, axis=1)
df.set_index('DHSID_EA', verify_integrity=True, inplace=True, drop=False) #had to add drop=False to keep column from disappearing  -- R
print(df['path'].iloc[0])
display(df.head())
# Out:
# /content/drive/Shareddrives/CS 230 231N/dhs_datasets/AL-2008-5#/AL-2008-5#-00000001.npz
#                                 DHSID_EA cname  year        lat        lon  \
# DHSID_EA
# AL-2008-5#-00000001  AL-2008-5#-00000001    AL  2008  40.822652  19.838321
# AL-2008-5#-00000002  AL-2008-5#-00000002    AL  2008  40.696846  20.007555
# AL-2008-5#-00000003  AL-2008-5#-00000003    AL  2008  40.750037  19.974262
# AL-2008-5#-00000004  AL-2008-5#-00000004    AL  2008  40.798931  19.863338
# AL-2008-5#-00000005  AL-2008-5#-00000005    AL  2008  40.746123  19.843885
#
#                      n_asset  asset_index  n_water  water_index  n_sanitation  \
# DHSID_EA
# AL-2008-5#-00000001     18.0     2.430596     18.0     3.444444          18.0
# AL-2008-5#-00000002     20.0     2.867678     20.0     4.700000          20.0
# AL-2008-5#-00000003     18.0     2.909049     18.0     4.500000          18.0
# AL-2008-5#-00000004     19.0     2.881122     19.0     4.947368          19.0
# AL-2008-5#-00000005     19.0     2.546830     19.0     4.684211          19.0
#
#                      ...  women_bmi  n_women_edu  n_women_bmi  cluster_id  \
# DHSID_EA             ...
# AL-2008-5#-00000001  ...  24.365000         18.0         18.0           1
# AL-2008-5#-00000002  ...  23.104000         20.0         20.0           2
# AL-2008-5#-00000003  ...  22.387778         18.0         18.0           3
# AL-2008-5#-00000004  ...  27.084500         21.0         20.0           4
# AL-2008-5#-00000005  ...  24.523125         16.0         16.0           5
#
#                      adm1fips  adm1dhs  urban      survey  cc  \
# DHSID_EA
# AL-2008-5#-00000001       NaN     9999      R  AL-2008-5#  AL
# AL-2008-5#-00000002       NaN     9999      R  AL-2008-5#  AL
# AL-2008-5#-00000003       NaN     9999      R  AL-2008-5#  AL
# AL-2008-5#-00000004       NaN     9999      R  AL-2008-5#  AL
# AL-2008-5#-00000005       NaN     9999      R  AL-2008-5#  AL
#
#                                                                   path
# DHSID_EA
# AL-2008-5#-00000001  /content/drive/Shareddrives/CS 230 231N/dhs_da...
# AL-2008-5#-00000002  /content/drive/Shareddrives/CS 230 231N/dhs_da...
# AL-2008-5#-00000003  /content/drive/Shareddrives/CS 230 231N/dhs_da...
# AL-2008-5#-00000004  /content/drive/Shareddrives/CS 230 231N/dhs_da...
# AL-2008-5#-00000005  /content/drive/Shareddrives/CS 230 231N/dhs_da...
#
# [5 rows x 24 columns]

# %%
label_cols = ['asset_index', 'under5_mort', 'women_bmi', 'women_edu', 'water_index', 'sanitation_index']

# %%
def calculate_nl_mean(path_and_year): # -> tuple[np.ndarray, np.ndarray, int]:
    '''
    Args
    - path_year: tuple (path, year)
      - path: str, path to npz file containing single entry 'x'
        representing a (C, H, W) image
      - year: int

    Returns: (nl_mean, year)
    '''
    dhsid_ea, npz_path, year = path_and_year
    img = np.load(npz_path)['x']  # shape (C, H, W)
    nl_mean = img[-1].mean(dtype=np.float64)
    return dhsid_ea, nl_mean, year

# %%
results_df = pd.DataFrame(
    data=np.nan,
    columns=['nl_mean', 'year'],
    index=pd.Index(sorted(df['DHSID_EA']), name='DHSID_EA')
)
results_df.head()
# Out:
#                      nl_mean  year
# DHSID_EA
# AL-2008-5#-00000001      NaN   NaN
# AL-2008-5#-00000002      NaN   NaN
# AL-2008-5#-00000003      NaN   NaN
# AL-2008-5#-00000004      NaN   NaN
# AL-2008-5#-00000005      NaN   NaN

# %%
with ThreadPoolExecutor(max_workers=30) as pool:
    inputs = path_years
    futures = pool.map(calculate_nl_mean, inputs)
    for dhsid_ea, nl_mean, year in tqdm(futures, total=len(inputs)):
        results_df.loc[dhsid_ea, ['nl_mean', 'year']] = (nl_mean, year)
# Out:
#   0%|          | 0/117644 [00:00<?, ?it/s]

# %%
results_df.to_csv('mean_nl.csv')

# %%
results_df['year'] = results_df['year'].astype(int)

# %%
SPLITS = {
    'train': [
        'AL', 'BD', 'CD', 'CM', 'GH', 'GU', 'HN', 'IA', 'ID', 'JO', 'KE', 'KM',
        'LB', 'LS', 'MA', 'MB', 'MD', 'MM', 'MW', 'MZ', 'NG', 'NI', 'PE', 'PH',
        'SN', 'TG', 'TJ', 'UG', 'ZM', 'ZW'],
    'val': [
        'BF', 'BJ', 'BO', 'CO', 'DR', 'GA', 'GN', 'GY', 'HT', 'NM', 'SL', 'TD',
        'TZ'],
    'test': [
        'AM', 'AO', 'BU', 'CI', 'EG', 'ET', 'KH', 'KY', 'ML', 'NP', 'PK', 'RW',
        'SZ']
}
SPLITS['trainval'] = SPLITS['train'] + SPLITS['val']

# %%
import scipy.stats
import sklearn.neighbors

# %%
results_df['cc'] = results_df.index.str[:2]

# %%
def run(knn, label, dmsp, trainsplit='train', testsplit='test'):
    if dmsp:
        year_mask = (df['year'] <= 2011)
    else:
        year_mask = (df['year'] > 2011)

    train_dhsids = df.index[year_mask & df['cc'].isin(SPLITS[trainsplit]) & df[label].notna()]
    test_dhsids = df.index[year_mask & df['cc'].isin(SPLITS[testsplit]) & df[label].notna()]

    train_X = results_df.loc[train_dhsids, 'nl_mean'].values.reshape(-1, 1)
    train_Y = df.loc[train_dhsids, label].values
    test_X = results_df.loc[test_dhsids, 'nl_mean'].values.reshape(-1, 1)
    test_Y = df.loc[test_dhsids, label].values

    knn.fit(train_X, train_Y)
    preds = knn.predict(test_X)
    return preds, test_Y

# %%
for label in label_cols:
    print(f'=========== {label:15s} ============')
    best_r2 = 0
    best_k = None
    for k in range(1, 21):
        knn = sklearn.neighbors.KNeighborsRegressor(
            n_neighbors=k, weights='uniform', algorithm='auto')
        preds_dmsp, labels_dmsp = run(knn, label, True, 'train', 'val')
        preds_viirs, labels_viirs = run(knn, label, False, 'train', 'val')
        r2 = scipy.stats.pearsonr(
            np.concatenate([preds_dmsp, preds_viirs]),
            np.concatenate([labels_dmsp, labels_viirs])
        )[0]**2
        print(f'k={k:2d}, {label:15s} r^2 = {r2:.3f}')
        if r2 > best_r2:
            best_r2 = r2
            best_k = k
    knn = sklearn.neighbors.KNeighborsRegressor(
            n_neighbors=best_k, weights='uniform', algorithm='auto')
    preds_dmsp, labels_dmsp = run(knn, label, True, 'trainval', 'test')
    preds_viirs, labels_viirs = run(knn, label, False, 'trainval', 'test')
    r2 = scipy.stats.pearsonr(
        np.concatenate([preds_dmsp, preds_viirs]),
        np.concatenate([labels_dmsp, labels_viirs])
    )[0]**2
    print(f'FINAL: k={best_k:2d}, {label:15s} r^2 = {r2:.2f}')
# Out:
# =========== asset_index     ============
# k= 1, asset_index     r^2 = 0.247
# k= 2, asset_index     r^2 = 0.339
# k= 3, asset_index     r^2 = 0.342
# k= 4, asset_index     r^2 = 0.351
# k= 5, asset_index     r^2 = 0.364
# k= 6, asset_index     r^2 = 0.383
# k= 7, asset_index     r^2 = 0.401
# k= 8, asset_index     r^2 = 0.396
# k= 9, asset_index     r^2 = 0.389
# k=10, asset_index     r^2 = 0.391
# k=11, asset_index     r^2 = 0.381
# k=12, asset_index     r^2 = 0.377
# k=13, asset_index     r^2 = 0.371
# k=14, asset_index     r^2 = 0.381
# k=15, asset_index     r^2 = 0.380
# k=16, asset_index     r^2 = 0.381
# k=17, asset_index     r^2 = 0.389
# k=18, asset_index     r^2 = 0.391
# k=19, asset_index     r^2 = 0.390
# k=20, asset_index     r^2 = 0.387
# FINAL: k= 7, asset_index     r^2 = 0.39
# =========== under5_mort     ============
# k= 1, under5_mort     r^2 = 0.000
# k= 2, under5_mort     r^2 = 0.001
# k= 3, under5_mort     r^2 = 0.000
# k= 4, under5_mort     r^2 = 0.000
# k= 5, under5_mort     r^2 = 0.000
# k= 6, under5_mort     r^2 = 0.000
# k= 7, under5_mort     r^2 = 0.001
# k= 8, under5_mort     r^2 = 0.001
# k= 9, under5_mort     r^2 = 0.001
# k=10, under5_mort     r^2 = 0.001
# k=11, under5_mort     r^2 = 0.002
# k=12, under5_mort     r^2 = 0.002
# k=13, under5_mort     r^2 = 0.002
# k=14, under5_mort     r^2 = 0.002
# k=15, under5_mort     r^2 = 0.002
# k=16, under5_mort     r^2 = 0.001
# k=17, under5_mort     r^2 = 0.001
# k=18, under5_mort     r^2 = 0.001
# k=19, under5_mort     r^2 = 0.001
# k=20, under5_mort     r^2 = 0.001
# FINAL: k=11, under5_mort     r^2 = 0.00
# =========== women_bmi       ============
# k= 1, women_bmi       r^2 = 0.044
# k= 2, women_bmi       r^2 = 0.064
# k= 3, women_bmi       r^2 = 0.097
# k= 4, women_bmi       r^2 = 0.107
# k= 5, women_bmi       r^2 = 0.121
# k= 6, women_bmi       r^2 = 0.127
# k= 7, women_bmi       r^2 = 0.123
# k= 8, women_bmi       r^2 = 0.131
# k= 9, women_bmi       r^2 = 0.130
# k=10, women_bmi       r^2 = 0.129
# k=11, women_bmi       r^2 = 0.132
# k=12, women_bmi       r^2 = 0.136
# k=13, women_bmi       r^2 = 0.136
# k=14, women_bmi       r^2 = 0.136
# k=15, women_bmi       r^2 = 0.137
# k=16, women_bmi       r^2 = 0.137
# k=17, women_bmi       r^2 = 0.136
# k=18, women_bmi       r^2 = 0.137
# k=19, women_bmi       r^2 = 0.139
# k=20, women_bmi       r^2 = 0.138
# FINAL: k=19, women_bmi       r^2 = 0.33
# =========== women_edu       ============
# k= 1, women_edu       r^2 = 0.127
# k= 2, women_edu       r^2 = 0.185
# k= 3, women_edu       r^2 = 0.228
# k= 4, women_edu       r^2 = 0.243
# k= 5, women_edu       r^2 = 0.253
# k= 6, women_edu       r^2 = 0.261
# k= 7, women_edu       r^2 = 0.266
# k= 8, women_edu       r^2 = 0.270
# k= 9, women_edu       r^2 = 0.272
# k=10, women_edu       r^2 = 0.275
# k=11, women_edu       r^2 = 0.276
# k=12, women_edu       r^2 = 0.276
# k=13, women_edu       r^2 = 0.273
# k=14, women_edu       r^2 = 0.274
# k=15, women_edu       r^2 = 0.279
# k=16, women_edu       r^2 = 0.278
# k=17, women_edu       r^2 = 0.279
# k=18, women_edu       r^2 = 0.281
# k=19, women_edu       r^2 = 0.285
# k=20, women_edu       r^2 = 0.285
# FINAL: k=20, women_edu       r^2 = 0.19
# =========== water_index     ============
# k= 1, water_index     r^2 = 0.092
# k= 2, water_index     r^2 = 0.173
# k= 3, water_index     r^2 = 0.201
# k= 4, water_index     r^2 = 0.220
# k= 5, water_index     r^2 = 0.240
# k= 6, water_index     r^2 = 0.236
# k= 7, water_index     r^2 = 0.239
# k= 8, water_index     r^2 = 0.270
# k= 9, water_index     r^2 = 0.275
# k=10, water_index     r^2 = 0.276
# k=11, water_index     r^2 = 0.284
# k=12, water_index     r^2 = 0.289
# k=13, water_index     r^2 = 0.296
# k=14, water_index     r^2 = 0.295
# k=15, water_index     r^2 = 0.294
# k=16, water_index     r^2 = 0.297
# k=17, water_index     r^2 = 0.295
# k=18, water_index     r^2 = 0.296
# k=19, water_index     r^2 = 0.295
# k=20, water_index     r^2 = 0.296
# FINAL: k=16, water_index     r^2 = 0.35
# =========== sanitation_index ============
# k= 1, sanitation_index r^2 = 0.145
# k= 2, sanitation_index r^2 = 0.215
# k= 3, sanitation_index r^2 = 0.269
# k= 4, sanitation_index r^2 = 0.290
# k= 5, sanitation_index r^2 = 0.300
# k= 6, sanitation_index r^2 = 0.303
# k= 7, sanitation_index r^2 = 0.310
# k= 8, sanitation_index r^2 = 0.313
# k= 9, sanitation_index r^2 = 0.323
# k=10, sanitation_index r^2 = 0.327
# k=11, sanitation_index r^2 = 0.327
# k=12, sanitation_index r^2 = 0.324
# k=13, sanitation_index r^2 = 0.328
# k=14, sanitation_index r^2 = 0.333
# k=15, sanitation_index r^2 = 0.341
# k=16, sanitation_index r^2 = 0.355
# k=17, sanitation_index r^2 = 0.356
# k=18, sanitation_index r^2 = 0.355
# k=19, sanitation_index r^2 = 0.354
# k=20, sanitation_index r^2 = 0.353
# FINAL: k=17, sanitation_index r^2 = 0.23
